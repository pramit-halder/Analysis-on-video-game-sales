# %% [markdown]
# # Importing dependencies

# %%
import pandas as pd
import seaborn as sb
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# # Loading the dataset

# %%
data = pd.read_csv("vgsales.csv")

# %%
data
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Removing null values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  int64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.5+ MB

# %%
pd.isnull(data).sum(axis=0)
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
pd.isnull(data).sum(axis=0)
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# ## 2. Converting the data type where required

# %%
data["Year"]=data["Year"].astype("int64")

# %%
data.sample(10)
# Out:
#         Rank                                            Name Platform  Year  \
# 13052  13054                     Summon Night X: Tears Crown       DS  2009
# 5074    5076  Shin Megami Tensei: Devil Survivor Overclocked      3DS  2011
# 10470  10472      Who Wants to Be a Millionaire: 3rd Edition      Wii  2010
# 6816    6818                                        G-Police       PS  1997
# 7549    7551                              Ashes Cricket 2009     X360  2009
# 1244    1246                           Football Manager 2012       PC  2011
# 11842  11844                                        G Darius       PS  1997
# 281      282                                       Half-Life       PC  1997
# 5378    5380                               Super Bust-A-Move      PS2  2000
# 5239    5241                            Super Robot Taisen A      GBA  2001
#
#               Genre              Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # Plots

# %% [markdown]
# ## 1. Platform

# %%
sb.set(rc={"figure.figsize":(20,20)})
plat_count = sb.countplot(x="Platform",data=data)
for bar in plat_count.containers:
    plat_count.bar_label(bar)

# %% [markdown]
# ### So, more number of games are released for DS.

# %%
na = data.groupby(["Platform"],as_index=False)["NA_Sales"].sum().sort_values(by="NA_Sales",ascending=False)
na_sales = sb.barplot(x="Platform",y="NA_Sales",data=na)
for bar in na_sales.containers:
    na_sales.bar_label(bar)

# %% [markdown]
# ### So, Games for X360 made the largest sale.

# %%
eu = data.groupby(["Platform"],as_index=False)["EU_Sales"].sum().sort_values(by="EU_Sales",ascending=False)
eu_sales = sb.barplot(x="Platform",y="EU_Sales",data=eu)
for bar in na_sales.containers:
    eu_sales.bar_label(bar)

# %% [markdown]
# ### Games for PS3 made the largest sale

# %%
gbl = data.groupby(["Platform"],as_index=False)["Global_Sales"].sum().sort_values(by="Global_Sales",ascending=False)
gbl_sales = sb.barplot(x="Platform",y="Global_Sales",data=gbl)
for bar in gbl_sales.containers:
    gbl_sales.bar_label(bar)

# %% [markdown]
# ### Many platforms or games have generated zero revenue, so count plot is not significant enough

# %%
year_count = sb.countplot(x="Year",data=data)
for bar in year_count.containers:
    year_count.bar_label(bar)

# %% [markdown]
# #### Highest no. of games were released in 2009

# %%
sb.set(rc={"figure.figsize":(20,15)})
genre_sales = data.groupby(["Genre"],as_index=False)["Global_Sales"].sum().sort_values(by="Global_Sales",ascending=False)
genre_plot = sb.barplot(x="Genre",y="Global_Sales",data=genre_sales)
for bar in genre_plot.containers:
    genre_plot.bar_label(bar)

# %%
sb.set(rc={"figure.figsize":(20,15)})
genre_sales = data.groupby(["Genre"],as_index=False)["NA_Sales"].sum().sort_values(by="NA_Sales",ascending=False)
genre_plot = sb.barplot(x="Genre",y="NA_Sales",data=genre_sales)
for bar in genre_plot.containers:
    genre_plot.bar_label(bar)

# %%
sb.set(rc={"figure.figsize":(20,15)})
genre_sales = data.groupby(["Genre"],as_index=False)["EU_Sales"].sum().sort_values(by="EU_Sales",ascending=False)
genre_plot = sb.barplot(x="Genre",y="EU_Sales",data=genre_sales)
for bar in genre_plot.containers:
    genre_plot.bar_label(bar)

# %%
sb.set(rc={"figure.figsize":(20,15)})
genre_sales = data.groupby(["Genre"],as_index=False)["JP_Sales"].sum().sort_values(by="JP_Sales",ascending=False)
genre_plot = sb.barplot(x="Genre",y="JP_Sales",data=genre_sales)
for bar in genre_plot.containers:
    genre_plot.bar_label(bar)

# %% [markdown]
# ### So, Action games are popular in North America, Europe and Globally, Role Playing games are popular in Japan

# %% [markdown]
# # Predicting the global sales on the basis of sales in NA,EU,JP and others.

# %%
df1 = data.drop(columns = ["Rank","Name","Platform","Year","Genre","Publisher"])
df1.head()
# Out:
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
X = df1.iloc[:,:4]
y = df1.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 0)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
acc = model.score(X_test,y_test)
print(f"The coeficients are :- {model.coef_}")
print(f"The intercept is :- {model.intercept_}")
print(acc)
# Out:
# The coeficients are :- [0.99991848 0.99995408 0.99992023 0.99973702]
# The intercept is :- 0.00030232200277136023
# 0.9999863067614225

# %%
from sklearn.metrics import r2_score
y_train_pred = model.predict(X_train)
acc_train = r2_score(y_train_pred,y_train)
acc_train
# Out:
# 0.9999894144959649

# %%
y_test_pred = model.predict(X_test)
acc_test = r2_score(y_test,y_test_pred)
acc_test
# Out:
# 0.9999863067614225
